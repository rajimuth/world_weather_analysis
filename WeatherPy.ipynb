# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
cities[50]
# Out:
# 'albany'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# # Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | dwarka
# Processing Record 3 of Set 1 | rong kwang
# Processing Record 4 of Set 1 | deputatskiy
# Processing Record 5 of Set 1 | olafsvik
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | hambantota
# Processing Record 11 of Set 1 | rio branco
# Processing Record 12 of Set 1 | sulangan
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | margate
# Processing Record 17 of Set 1 | craig
# Processing Record 18 of Set 1 | varna
# Processing Record 19 of Set 1 | hofn
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | naze
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | beringovskiy
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | nyrob
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | tahoua
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | rohru
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | tabialan
# City not found. Skipping...
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | shakiso
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | constitucion
# Processing Record 39 of Set 1 | bima
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | vitina
# Processing Record 45 of Set 1 | kloulklubed
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | geraldton
# Processing Record 48 of Set 1 | mount gambier
# Processing Record 49 of Set 1 | mengen
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | berdigestyakh
# Processing Record 3 of Set 2 | jurado
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | dingle
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | cabo san lucas
# Processing Record 10 of Set 2 | avera
# Processing Record 11 of Set 2 | port lincoln
# Processing Record 12 of Set 2 | aguimes
# Processing Record 13 of Set 2 | tazmalt
# Processing Record 14 of Set 2 | ranau
# Processing Record 15 of Set 2 | sao filipe
# Processing Record 16 of Set 2 | mahebourg
# Processing Record 17 of Set 2 | airai
# Processing Record 18 of Set 2 | roma
# Processing Record 19 of Set 2 | portland
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | erdenet
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | hattiesburg
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | canutama
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | meulaboh
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | mocuba
# Processing Record 31 of Set 2 | san quintin
# Processing Record 32 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 2 | nanortalik
# Processing Record 34 of Set 2 | nova soure
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | porto torres
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | boa vista
# Processing Record 40 of Set 2 | pundaguitan
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | ajdabiya
# Processing Record 43 of Set 2 | acajutla
# Processing Record 44 of Set 2 | vestmannaeyjar
# Processing Record 45 of Set 2 | vilyuysk
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | arman
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | nemuro
# Processing Record 50 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | rio grande
# Processing Record 4 of Set 3 | sherbakul
# Processing Record 5 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | gopinathpur
# Processing Record 9 of Set 3 | frederikshavn
# Processing Record 10 of Set 3 | honnali
# Processing Record 11 of Set 3 | lasa
# Processing Record 12 of Set 3 | xining
# Processing Record 13 of Set 3 | divnoye
# Processing Record 14 of Set 3 | saint-francois
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | la ronge
# Processing Record 17 of Set 3 | krasnyy kholm
# Processing Record 18 of Set 3 | lumphat
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | san policarpo
# Processing Record 23 of Set 3 | ranong
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | middle island
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | nikolskoye
# Processing Record 29 of Set 3 | isangel
# Processing Record 30 of Set 3 | havre-saint-pierre
# Processing Record 31 of Set 3 | lorengau
# Processing Record 32 of Set 3 | krasnyy chikoy
# Processing Record 33 of Set 3 | rawson
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | da lat
# Processing Record 36 of Set 3 | nishihara
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | bambanglipuro
# Processing Record 42 of Set 3 | middelburg
# Processing Record 43 of Set 3 | uige
# Processing Record 44 of Set 3 | tongren
# Processing Record 45 of Set 3 | danielskuil
# Processing Record 46 of Set 3 | esperance
# Processing Record 47 of Set 3 | vila franca do campo
# Processing Record 48 of Set 3 | namatanai
# Processing Record 49 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 3 | kailua
# Processing Record 1 of Set 4 | vallenar
# Processing Record 2 of Set 4 | canmore
# Processing Record 3 of Set 4 | mizdah
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | fontem
# Processing Record 6 of Set 4 | agaro
# Processing Record 7 of Set 4 | castro
# Processing Record 8 of Set 4 | salalah
# Processing Record 9 of Set 4 | hasaki
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | cayenne
# Processing Record 12 of Set 4 | iqaluit
# Processing Record 13 of Set 4 | nizwa
# Processing Record 14 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 4 | belaya gora
# Processing Record 16 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 4 | along
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | port-gentil
# Processing Record 20 of Set 4 | half moon bay
# Processing Record 21 of Set 4 | chicama
# Processing Record 22 of Set 4 | jalu
# Processing Record 23 of Set 4 | nome
# Processing Record 24 of Set 4 | suamico
# Processing Record 25 of Set 4 | port moresby
# Processing Record 26 of Set 4 | port blair
# Processing Record 27 of Set 4 | westport
# Processing Record 28 of Set 4 | axim
# Processing Record 29 of Set 4 | karratha
# Processing Record 30 of Set 4 | ulcinj
# Processing Record 31 of Set 4 | kavieng
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | mezhdurechenskiy
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | borovoy
# Processing Record 36 of Set 4 | pitimbu
# Processing Record 37 of Set 4 | port shepstone
# Processing Record 38 of Set 4 | husavik
# Processing Record 39 of Set 4 | honiara
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | tonekabon
# Processing Record 42 of Set 4 | tanshui
# City not found. Skipping...
# Processing Record 43 of Set 4 | ciudad bolivar
# Processing Record 44 of Set 4 | lively
# Processing Record 45 of Set 4 | nueve de julio
# Processing Record 46 of Set 4 | cherskiy
# Processing Record 47 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 48 of Set 4 | paita
# Processing Record 49 of Set 4 | novyy urengoy
# Processing Record 50 of Set 4 | san jeronimo
# Processing Record 1 of Set 5 | estelle
# Processing Record 2 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 4 of Set 5 | borovichi
# Processing Record 5 of Set 5 | stornoway
# Processing Record 6 of Set 5 | east london
# Processing Record 7 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 5 | necochea
# Processing Record 9 of Set 5 | mattawa
# Processing Record 10 of Set 5 | quatre cocos
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | wajima
# Processing Record 15 of Set 5 | luderitz
# Processing Record 16 of Set 5 | jagalur
# Processing Record 17 of Set 5 | songjianghe
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | butembo
# Processing Record 20 of Set 5 | longyearbyen
# Processing Record 21 of Set 5 | high rock
# Processing Record 22 of Set 5 | chabahar
# Processing Record 23 of Set 5 | vredendal
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | pangnirtung
# Processing Record 26 of Set 5 | juneau
# Processing Record 27 of Set 5 | abnub
# Processing Record 28 of Set 5 | jibuti
# Processing Record 29 of Set 5 | arraial do cabo
# Processing Record 30 of Set 5 | arys
# Processing Record 31 of Set 5 | saskylakh
# Processing Record 32 of Set 5 | vila velha
# Processing Record 33 of Set 5 | viedma
# Processing Record 34 of Set 5 | meadow lake
# Processing Record 35 of Set 5 | tezu
# Processing Record 36 of Set 5 | ketchikan
# Processing Record 37 of Set 5 | tuatapere
# Processing Record 38 of Set 5 | dzhubga
# Processing Record 39 of Set 5 | zhaodong
# Processing Record 40 of Set 5 | santa cruz del norte
# Processing Record 41 of Set 5 | namtsy
# Processing Record 42 of Set 5 | samarai
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 5 | skibbereen
# Processing Record 46 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 5 | conceicao da barra
# Processing Record 48 of Set 5 | ternova
# Processing Record 49 of Set 5 | cockburn town
# Processing Record 50 of Set 5 | kissidougou
# Processing Record 1 of Set 6 | saint-philippe
# Processing Record 2 of Set 6 | marsh harbour
# Processing Record 3 of Set 6 | comodoro rivadavia
# Processing Record 4 of Set 6 | henties bay
# Processing Record 5 of Set 6 | provideniya
# Processing Record 6 of Set 6 | inta
# Processing Record 7 of Set 6 | west plains
# Processing Record 8 of Set 6 | hun
# Processing Record 9 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 10 of Set 6 | shingu
# Processing Record 11 of Set 6 | ahuimanu
# Processing Record 12 of Set 6 | prado
# Processing Record 13 of Set 6 | vangaindrano
# Processing Record 14 of Set 6 | xichang
# Processing Record 15 of Set 6 | emba
# Processing Record 16 of Set 6 | yakeshi
# Processing Record 17 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 6 | soe
# Processing Record 19 of Set 6 | ikongo
# Processing Record 20 of Set 6 | marzuq
# Processing Record 21 of Set 6 | northam
# Processing Record 22 of Set 6 | lavrentiya
# Processing Record 23 of Set 6 | klyuchi
# Processing Record 24 of Set 6 | guerrero negro
# Processing Record 25 of Set 6 | ahipara
# Processing Record 26 of Set 6 | chongwe
# Processing Record 27 of Set 6 | varska
# City not found. Skipping...
# Processing Record 28 of Set 6 | padang
# Processing Record 29 of Set 6 | tobermory
# Processing Record 30 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 6 | muscat
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | honningsvag
# Processing Record 34 of Set 6 | makakilo city
# Processing Record 35 of Set 6 | batemans bay
# Processing Record 36 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 6 | waingapu
# Processing Record 38 of Set 6 | bratsk
# Processing Record 39 of Set 6 | fortuna
# Processing Record 40 of Set 6 | moussoro
# Processing Record 41 of Set 6 | clyde river
# Processing Record 42 of Set 6 | akdepe
# Processing Record 43 of Set 6 | souillac
# Processing Record 44 of Set 6 | san cristobal
# Processing Record 45 of Set 6 | manta
# Processing Record 46 of Set 6 | brae
# Processing Record 47 of Set 6 | manavalakurichi
# Processing Record 48 of Set 6 | faanui
# Processing Record 49 of Set 6 | verkhovazhye
# Processing Record 50 of Set 6 | rutana
# Processing Record 1 of Set 7 | abasolo
# Processing Record 2 of Set 7 | bunda
# Processing Record 3 of Set 7 | staunton
# Processing Record 4 of Set 7 | oxford
# Processing Record 5 of Set 7 | benin
# Processing Record 6 of Set 7 | la rioja
# Processing Record 7 of Set 7 | broome
# Processing Record 8 of Set 7 | jaciara
# Processing Record 9 of Set 7 | enshi
# Processing Record 10 of Set 7 | charters towers
# Processing Record 11 of Set 7 | kandalaksha
# Processing Record 12 of Set 7 | wembley
# Processing Record 13 of Set 7 | mayo
# Processing Record 14 of Set 7 | aki
# Processing Record 15 of Set 7 | bonavista
# Processing Record 16 of Set 7 | bocanda
# Processing Record 17 of Set 7 | port hardy
# Processing Record 18 of Set 7 | linxi
# Processing Record 19 of Set 7 | marsaxlokk
# Processing Record 20 of Set 7 | yabelo
# Processing Record 21 of Set 7 | banjar
# Processing Record 22 of Set 7 | mbeya
# Processing Record 23 of Set 7 | qui nhon
# Processing Record 24 of Set 7 | jizan
# Processing Record 25 of Set 7 | saint-pierre
# Processing Record 26 of Set 7 | cacu
# Processing Record 27 of Set 7 | sechura
# Processing Record 28 of Set 7 | touros
# Processing Record 29 of Set 7 | vung tau
# Processing Record 30 of Set 7 | bagotville
# Processing Record 31 of Set 7 | itarema
# Processing Record 32 of Set 7 | galle
# Processing Record 33 of Set 7 | albert lea
# Processing Record 34 of Set 7 | vila
# Processing Record 35 of Set 7 | nim ka thana
# City not found. Skipping...
# Processing Record 36 of Set 7 | menongue
# Processing Record 37 of Set 7 | tamandare
# Processing Record 38 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 39 of Set 7 | grand island
# Processing Record 40 of Set 7 | freetown
# Processing Record 41 of Set 7 | ponta delgada
# Processing Record 42 of Set 7 | veraval
# Processing Record 43 of Set 7 | aykhal
# Processing Record 44 of Set 7 | fallon
# Processing Record 45 of Set 7 | yarada
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | buturlino
# Processing Record 48 of Set 7 | komsomolskiy
# Processing Record 49 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 50 of Set 7 | sapao
# City not found. Skipping...
# Processing Record 1 of Set 8 | yenagoa
# Processing Record 2 of Set 8 | ouro fino
# Processing Record 3 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 8 | yaan
# Processing Record 5 of Set 8 | klaksvik
# Processing Record 6 of Set 8 | los llanos de aridane
# Processing Record 7 of Set 8 | ostrovnoy
# Processing Record 8 of Set 8 | petrolina
# Processing Record 9 of Set 8 | pathein
# Processing Record 10 of Set 8 | pimentel
# Processing Record 11 of Set 8 | lata
# Processing Record 12 of Set 8 | nuuk
# Processing Record 13 of Set 8 | sinnamary
# Processing Record 14 of Set 8 | crestview
# Processing Record 15 of Set 8 | willmar
# Processing Record 16 of Set 8 | simao
# Processing Record 17 of Set 8 | makarov
# Processing Record 18 of Set 8 | yima
# Processing Record 19 of Set 8 | jambi
# Processing Record 20 of Set 8 | bereda
# Processing Record 21 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 8 | hickory
# Processing Record 24 of Set 8 | san patricio
# Processing Record 25 of Set 8 | kortkeros
# Processing Record 26 of Set 8 | saint george
# Processing Record 27 of Set 8 | torrevieja
# Processing Record 28 of Set 8 | ostersund
# Processing Record 29 of Set 8 | grand gaube
# Processing Record 30 of Set 8 | puerto del rosario
# Processing Record 31 of Set 8 | diamantino
# Processing Record 32 of Set 8 | sairang
# Processing Record 33 of Set 8 | guanica
# Processing Record 34 of Set 8 | ocos
# Processing Record 35 of Set 8 | saint-quentin
# Processing Record 36 of Set 8 | gualeguay
# Processing Record 37 of Set 8 | tongliao
# Processing Record 38 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 8 | lambare
# Processing Record 40 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 8 | virginia beach
# Processing Record 42 of Set 8 | patnanungan
# Processing Record 43 of Set 8 | quelimane
# Processing Record 44 of Set 8 | maamba
# Processing Record 45 of Set 8 | susanville
# Processing Record 46 of Set 8 | igrim
# Processing Record 47 of Set 8 | kelvington
# Processing Record 48 of Set 8 | ayan
# Processing Record 49 of Set 8 | pasuruan
# Processing Record 50 of Set 8 | villa maria
# Processing Record 1 of Set 9 | fairlie
# Processing Record 2 of Set 9 | talaya
# Processing Record 3 of Set 9 | daru
# Processing Record 4 of Set 9 | matagami
# Processing Record 5 of Set 9 | acapulco
# Processing Record 6 of Set 9 | lamu
# Processing Record 7 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 8 of Set 9 | hutchinson
# Processing Record 9 of Set 9 | khasan
# Processing Record 10 of Set 9 | kahului
# Processing Record 11 of Set 9 | halifax
# Processing Record 12 of Set 9 | solnechnyy
# Processing Record 13 of Set 9 | rajakhera
# Processing Record 14 of Set 9 | kindu
# Processing Record 15 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 9 | marica
# Processing Record 17 of Set 9 | vardo
# Processing Record 18 of Set 9 | karasjok
# Processing Record 19 of Set 9 | caucaia
# Processing Record 20 of Set 9 | naliya
# Processing Record 21 of Set 9 | bathsheba
# Processing Record 22 of Set 9 | richards bay
# Processing Record 23 of Set 9 | dubai
# Processing Record 24 of Set 9 | istok
# Processing Record 25 of Set 9 | grindavik
# Processing Record 26 of Set 9 | tilichiki
# Processing Record 27 of Set 9 | marawi
# Processing Record 28 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 9 | road town
# Processing Record 30 of Set 9 | gulu
# Processing Record 31 of Set 9 | nabire
# Processing Record 32 of Set 9 | barinitas
# Processing Record 33 of Set 9 | buraydah
# Processing Record 34 of Set 9 | pechenga
# Processing Record 35 of Set 9 | sitka
# Processing Record 36 of Set 9 | toora-khem
# Processing Record 37 of Set 9 | saldanha
# Processing Record 38 of Set 9 | pouebo
# Processing Record 39 of Set 9 | koungheul
# Processing Record 40 of Set 9 | muroto
# Processing Record 41 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 9 | hobyo
# Processing Record 43 of Set 9 | kavaratti
# Processing Record 44 of Set 9 | sao felix do xingu
# Processing Record 45 of Set 9 | payo
# Processing Record 46 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 9 | mahon
# Processing Record 48 of Set 9 | utevka
# Processing Record 49 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 9 | sipe sipe
# Processing Record 1 of Set 10 | yertsevo
# Processing Record 2 of Set 10 | ulaangom
# Processing Record 3 of Set 10 | azovo
# Processing Record 4 of Set 10 | shetpe
# Processing Record 5 of Set 10 | jonesboro
# Processing Record 6 of Set 10 | tanggu
# Processing Record 7 of Set 10 | puerto escondido
# Processing Record 8 of Set 10 | moroni
# Processing Record 9 of Set 10 | kholm
# Processing Record 10 of Set 10 | flin flon
# Processing Record 11 of Set 10 | mandalgovi
# Processing Record 12 of Set 10 | price
# Processing Record 13 of Set 10 | miguel pereira
# Processing Record 14 of Set 10 | dubbo
# Processing Record 15 of Set 10 | townsville
# Processing Record 16 of Set 10 | rio gallegos
# Processing Record 17 of Set 10 | nouadhibou
# Processing Record 18 of Set 10 | jalali
# Processing Record 19 of Set 10 | sayyan
# Processing Record 20 of Set 10 | rock springs
# Processing Record 21 of Set 10 | prabumulih
# Processing Record 22 of Set 10 | shaunavon
# Processing Record 23 of Set 10 | abu samrah
# Processing Record 24 of Set 10 | chapais
# Processing Record 25 of Set 10 | gobabis
# Processing Record 26 of Set 10 | dunedin
# Processing Record 27 of Set 10 | turukhansk
# Processing Record 28 of Set 10 | yerbogachen
# Processing Record 29 of Set 10 | burica
# City not found. Skipping...
# Processing Record 30 of Set 10 | we
# City not found. Skipping...
# Processing Record 31 of Set 10 | koson
# Processing Record 32 of Set 10 | merauke
# Processing Record 33 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 10 | sechelt
# Processing Record 35 of Set 10 | baloda
# Processing Record 36 of Set 10 | alexandria
# Processing Record 37 of Set 10 | hirara
# Processing Record 38 of Set 10 | mildura
# Processing Record 39 of Set 10 | mozarlandia
# Processing Record 40 of Set 10 | olinda
# Processing Record 41 of Set 10 | dryden
# Processing Record 42 of Set 10 | bardzrashen
# Processing Record 43 of Set 10 | indramayu
# Processing Record 44 of Set 10 | lakes entrance
# Processing Record 45 of Set 10 | mnogovershinnyy
# Processing Record 46 of Set 10 | korla
# Processing Record 47 of Set 10 | huarmey
# Processing Record 48 of Set 10 | glendora
# Processing Record 49 of Set 10 | ghanzi
# Processing Record 50 of Set 10 | opuwo
# Processing Record 1 of Set 11 | lerwick
# Processing Record 2 of Set 11 | kruisfontein
# Processing Record 3 of Set 11 | tiko
# Processing Record 4 of Set 11 | ballina
# Processing Record 5 of Set 11 | kostino
# Processing Record 6 of Set 11 | pangody
# Processing Record 7 of Set 11 | melfi
# Processing Record 8 of Set 11 | tura
# Processing Record 9 of Set 11 | cubuk
# Processing Record 10 of Set 11 | moose factory
# Processing Record 11 of Set 11 | robertsonpet
# Processing Record 12 of Set 11 | imbituba
# Processing Record 13 of Set 11 | tessalit
# Processing Record 14 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 11 | mantua
# Processing Record 16 of Set 11 | sonkovo
# Processing Record 17 of Set 11 | obera
# Processing Record 18 of Set 11 | ola
# Processing Record 19 of Set 11 | palmerston
# Processing Record 20 of Set 11 | tarata
# Processing Record 21 of Set 11 | natal
# Processing Record 22 of Set 11 | kulachi
# Processing Record 23 of Set 11 | pittsfield
# Processing Record 24 of Set 11 | raudeberg
# Processing Record 25 of Set 11 | paamiut
# Processing Record 26 of Set 11 | saint anthony
# Processing Record 27 of Set 11 | stykkisholmur
# Processing Record 28 of Set 11 | mpika
# Processing Record 29 of Set 11 | alofi
# Processing Record 30 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 11 | ancud
# Processing Record 32 of Set 11 | calbuco
# Processing Record 33 of Set 11 | baykit
# Processing Record 34 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 11 | bubaque
# Processing Record 36 of Set 11 | mineiros
# Processing Record 37 of Set 11 | aklavik
# Processing Record 38 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 39 of Set 11 | glens falls
# Processing Record 40 of Set 11 | lubyany
# Processing Record 41 of Set 11 | loukhi
# Processing Record 42 of Set 11 | nakur
# Processing Record 43 of Set 11 | langedijk
# Processing Record 44 of Set 11 | asau
# Processing Record 45 of Set 11 | dubovka
# Processing Record 46 of Set 11 | dhidhdhoo
# Processing Record 47 of Set 11 | penzance
# Processing Record 48 of Set 11 | behshahr
# Processing Record 49 of Set 11 | kagoro
# Processing Record 50 of Set 11 | sur
# Processing Record 1 of Set 12 | riyadh
# Processing Record 2 of Set 12 | ambilobe
# Processing Record 3 of Set 12 | atar
# Processing Record 4 of Set 12 | lodja
# Processing Record 5 of Set 12 | marsabit
# Processing Record 6 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 12 | ginda
# Processing Record 8 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 12 | vostok
# Processing Record 10 of Set 12 | high level
# Processing Record 11 of Set 12 | praia
# Processing Record 12 of Set 12 | cascais
# Processing Record 13 of Set 12 | narsaq
# Processing Record 14 of Set 12 | ziro
# Processing Record 15 of Set 12 | glenwood springs
# Processing Record 16 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 12 | sonoita
# Processing Record 18 of Set 12 | sanary-sur-mer
# Processing Record 19 of Set 12 | san miguel
# Processing Record 20 of Set 12 | ati
# Processing Record 21 of Set 12 | isfana
# Processing Record 22 of Set 12 | tulun
# Processing Record 23 of Set 12 | port-cartier
# Processing Record 24 of Set 12 | matsusaka
# Processing Record 25 of Set 12 | mmabatho
# Processing Record 26 of Set 12 | urumqi
# Processing Record 27 of Set 12 | codrington
# Processing Record 28 of Set 12 | eyrarbakki
# Processing Record 29 of Set 12 | hay river
# Processing Record 30 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 31 of Set 12 | san andres
# Processing Record 32 of Set 12 | wuwei
# Processing Record 33 of Set 12 | tocopilla
# Processing Record 34 of Set 12 | rudbar
# Processing Record 35 of Set 12 | aksarka
# Processing Record 36 of Set 12 | bandarbeyla
# Processing Record 37 of Set 12 | kaohsiung
# Processing Record 38 of Set 12 | suntar
# Processing Record 39 of Set 12 | tucupita
# Processing Record 40 of Set 12 | hoshcha
# Processing Record 41 of Set 12 | wewak
# Processing Record 42 of Set 12 | saint-paul
# Processing Record 43 of Set 12 | monitos
# Processing Record 44 of Set 12 | coihaique
# Processing Record 45 of Set 12 | bagdarin
# Processing Record 46 of Set 12 | pau
# Processing Record 47 of Set 12 | winona
# Processing Record 48 of Set 12 | tornio
# Processing Record 49 of Set 12 | manaquiri
# Processing Record 50 of Set 12 | masuda
# Processing Record 1 of Set 13 | ayagoz
# Processing Record 2 of Set 13 | acari
# Processing Record 3 of Set 13 | espera feliz
# Processing Record 4 of Set 13 | port lavaca
# Processing Record 5 of Set 13 | tabou
# Processing Record 6 of Set 13 | santa rosa
# Processing Record 7 of Set 13 | tarko-sale
# Processing Record 8 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 13 | paracin
# Processing Record 10 of Set 13 | troitsko-pechorsk
# Processing Record 11 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 13 | najran
# Processing Record 13 of Set 13 | baft
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 558

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Cape Town -33.9258   18.4232     67.26        69           0        1.99
# 1       Dwarka  22.2394   68.9678     66.70        50           2        8.66
# 2   Rong Kwang  18.3390  100.3174     67.55        49          45        1.50
# 3  Deputatskiy  69.3000  139.9000    -25.28        99          99        1.74
# 4     Olafsvik  64.8945  -23.7142     23.20        66          67       17.69
# 5       Kodiak  57.7900 -152.4072     26.11        74         100       18.41
# 6       Atuona  -9.8000 -139.0333     77.81        71           9       14.16
# 7      Mataura -46.1927  168.8643     71.31        35          96        4.99
# 8   Hambantota   6.1241   81.1185     74.16        88          40        5.10
# 9   Rio Branco  -9.9747  -67.8100     77.61       100          75        0.00
#
#   Country                 Date
# 0      ZA  2022-01-28 23:25:36
# 1      IN  2022-01-28 23:25:17
# 2      TH  2022-01-28 23:25:37
# 3      RU  2022-01-28 23:25:37
# 4      IS  2022-01-28 23:25:37
# 5      US  2022-01-28 23:25:38
# 6      PF  2022-01-28 23:25:38
# 7      NZ  2022-01-28 23:25:39
# 8      LK  2022-01-28 23:25:39
# 9      BR  2022-01-28 23:25:39

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df =city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Cape Town      ZA  2022-01-28 23:25:36 -33.9258   18.4232     67.26
# 1       Dwarka      IN  2022-01-28 23:25:17  22.2394   68.9678     66.70
# 2   Rong Kwang      TH  2022-01-28 23:25:37  18.3390  100.3174     67.55
# 3  Deputatskiy      RU  2022-01-28 23:25:37  69.3000  139.9000    -25.28
# 4     Olafsvik      IS  2022-01-28 23:25:37  64.8945  -23.7142     23.20
#
#    Humidity  Cloudiness  Wind Speed
# 0        69           0        1.99
# 1        50           2        8.66
# 2        49          45        1.50
# 3        99          99        1.74
# 4        66          67       17.69

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.head(3)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0   Cape Town      ZA  2022-01-28 23:25:36 -33.9258   18.4232     67.26
# 1      Dwarka      IN  2022-01-28 23:25:17  22.2394   68.9678     66.70
# 2  Rong Kwang      TH  2022-01-28 23:25:37  18.3390  100.3174     67.55
#
#    Humidity  Cloudiness  Wind Speed
# 0        69           0        1.99
# 1        50           2        8.66
# 2        49          45        1.50

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1643426153.9669302

# %%
today = time.strftime("%x")
today
# Out:
# '01/28/22'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,max_temps, edgecolor="black",linewidths=1,marker="o",alpha=0.8,label="Cities")
plt.title("City latitude vs Max temperature"+" "+str(today))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.grid(True)
plt.show()
# Save the fifure
plt.savefig("weather_data/Fig1.png")

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
     # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    print(f"The p-value is: {p_value:.3f}")
    plt.show()

# %%
plot_linear_regression(lats, max_temps,"City latitude vs Max temperature"+" "+str(today), "Max Temperature(F)", (-60,-20))
# Save the fifure
plt.savefig("weather_data/lat_vs_temp.png")
# Out:
# The p-value is: 0.000

# %%
plot_linear_regression(lats, humidity,"City latitude vs Humidity"+" "+str(today), "Humidity", (-60,20))
plt.savefig("weather_data/lat_vs_hum.png")
# Out:
# The p-value is: 0.000

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Create a scatter plot of the x and y values.
plt.scatter(lats,max_temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (-60,-20), fontsize=15, color="red")
plt.title("City latitude vs Max temperature"+" "+str(today))
plt.xlabel('Latitude')
plt.ylabel("Max Temperature(F)")
plt.show()

# %%
# # Build the scatter plot for latitude vs. max temperature.
# city_data_df.plot(kind="scatter", x="Lat", y="Max Temp")
# plt.title("City latitude vs Max temperature"+" "+str(today))
# plt.xlabel("Latitude")
# plt.ylabel("Max Temperature(F)")
# plt.grid(True)
# plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,humidity, edgecolor="black",linewidths=1,marker="o",alpha=0.8,label="Cities")
plt.title("City latitude vs Humidity"+" "+str(today))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)
plt.show()
# Save the figure
plt.savefig("weather_data/Fig2.png")

# %%
plot_linear_regression(lats, cloudiness,"City latitude vs Cloudiness"+" "+str(today), "Cloudiness", (40,40))
plt.savefig("weather_data/lat_vs_cloud.png")
# Out:
# The p-value is: 0.000

# %%
# Build the scatter plot for latitude vs. wind speed.
plt.scatter(lats,cloudiness, edgecolor="black",linewidths=1,marker="o",alpha=0.8,label="Cities")
plt.title("City latitude vs Cloudiness"+" "+str(today))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)
plt.show()
# Save the figure
plt.savefig("weather_data/Fig3.png")

# %%
plot_linear_regression(lats, wind_speed,"City latitude vs Wind Speed"+" "+str(today), "Wind speed", (-60,40))
plt.savefig("weather_data/lat_vs_windspeed.png")
# Out:
# The p-value is: 0.682

# %%
# Build the scatter plot for latitude vs. wind speed.
plt.scatter(lats,wind_speed, edgecolor="black",linewidths=1,marker="o",alpha=0.8,label="Cities")
plt.title("City latitude vs Wind Speed"+" "+str(today))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)
plt.show()
# Save the figure
plt.savefig("weather_data/Fig4.png")

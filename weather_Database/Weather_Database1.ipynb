# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint

# %% [markdown]
# Deliverable 1: Retrieve Weather Data

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
cities[50]
# Out:
# 'san patricio'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# # Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
from pprint import pprint

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_Weather_Des=(city_weather)["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_Weather_Des })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | ketchikan
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | tabou
# Processing Record 9 of Set 1 | quang ngai
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | szilvasvarad
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | codrington
# Processing Record 15 of Set 1 | alice springs
# Processing Record 16 of Set 1 | xichang
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | beitbridge
# Processing Record 22 of Set 1 | steinbach
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | litovko
# Processing Record 25 of Set 1 | palmer
# Processing Record 26 of Set 1 | mahibadhoo
# Processing Record 27 of Set 1 | porto novo
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | flin flon
# Processing Record 35 of Set 1 | juliaca
# Processing Record 36 of Set 1 | tautira
# Processing Record 37 of Set 1 | sao luiz gonzaga
# Processing Record 38 of Set 1 | necochea
# Processing Record 39 of Set 1 | salym
# Processing Record 40 of Set 1 | cairns
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | tromso
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | northam
# Processing Record 45 of Set 1 | mahajanga
# Processing Record 46 of Set 1 | kalmunai
# Processing Record 47 of Set 1 | biak
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 1 | vanavara
# Processing Record 1 of Set 2 | san patricio
# Processing Record 2 of Set 2 | shipitsyno
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | malindi
# Processing Record 6 of Set 2 | shushenskoye
# Processing Record 7 of Set 2 | gisborne
# Processing Record 8 of Set 2 | golkoy
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | manggar
# Processing Record 12 of Set 2 | sergeyevka
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | vohibinany
# Processing Record 15 of Set 2 | slave lake
# Processing Record 16 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 2 | larsnes
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | libreville
# Processing Record 21 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 2 | kavieng
# Processing Record 23 of Set 2 | grindavik
# Processing Record 24 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 2 | puri
# Processing Record 26 of Set 2 | ushuaia
# Processing Record 27 of Set 2 | tutoia
# Processing Record 28 of Set 2 | millau
# Processing Record 29 of Set 2 | jawhar
# Processing Record 30 of Set 2 | namibe
# Processing Record 31 of Set 2 | neiafu
# Processing Record 32 of Set 2 | camabatela
# Processing Record 33 of Set 2 | hambantota
# Processing Record 34 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | chatsu
# City not found. Skipping...
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | isangel
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | busselton
# Processing Record 41 of Set 2 | samarai
# Processing Record 42 of Set 2 | beya
# Processing Record 43 of Set 2 | sistranda
# Processing Record 44 of Set 2 | anaconda
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | mogadishu
# Processing Record 48 of Set 2 | turayf
# Processing Record 49 of Set 2 | hasaki
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | charters towers
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | bengkulu
# Processing Record 5 of Set 3 | lagoa
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | ratnapura
# Processing Record 8 of Set 3 | hay river
# Processing Record 9 of Set 3 | bogovarovo
# Processing Record 10 of Set 3 | lorengau
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | nuuk
# Processing Record 13 of Set 3 | rawah
# Processing Record 14 of Set 3 | bonthe
# Processing Record 15 of Set 3 | whyalla
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | zhanaozen
# Processing Record 18 of Set 3 | tahta
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | lashio
# Processing Record 21 of Set 3 | sungai kolok
# City not found. Skipping...
# Processing Record 22 of Set 3 | la plaine
# Processing Record 23 of Set 3 | na wa
# Processing Record 24 of Set 3 | yar-sale
# Processing Record 25 of Set 3 | corrente
# Processing Record 26 of Set 3 | haines junction
# Processing Record 27 of Set 3 | capinota
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | leh
# Processing Record 30 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 3 | nanortalik
# Processing Record 32 of Set 3 | broome
# Processing Record 33 of Set 3 | srandakan
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | corner brook
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | apple valley
# Processing Record 38 of Set 3 | solnechnyy
# Processing Record 39 of Set 3 | swinoujscie
# Processing Record 40 of Set 3 | guaruja
# Processing Record 41 of Set 3 | lithgow
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | adre
# Processing Record 46 of Set 3 | davila
# Processing Record 47 of Set 3 | chegdomyn
# Processing Record 48 of Set 3 | svetlaya
# Processing Record 49 of Set 3 | souillac
# Processing Record 50 of Set 3 | jinxiang
# Processing Record 1 of Set 4 | saint-francois
# Processing Record 2 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | sabang
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | morden
# Processing Record 7 of Set 4 | winneba
# Processing Record 8 of Set 4 | cuenca
# Processing Record 9 of Set 4 | ukiah
# Processing Record 10 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 4 | bajil
# Processing Record 12 of Set 4 | taoudenni
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | luderitz
# Processing Record 15 of Set 4 | katangli
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 4 | zhob
# Processing Record 19 of Set 4 | sioux lookout
# Processing Record 20 of Set 4 | buala
# Processing Record 21 of Set 4 | nyurba
# Processing Record 22 of Set 4 | sitka
# Processing Record 23 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 4 | cherskiy
# Processing Record 25 of Set 4 | mount isa
# Processing Record 26 of Set 4 | kaitangata
# Processing Record 27 of Set 4 | segezha
# Processing Record 28 of Set 4 | le mans
# Processing Record 29 of Set 4 | dzhebariki-khaya
# Processing Record 30 of Set 4 | lata
# Processing Record 31 of Set 4 | kungsbacka
# Processing Record 32 of Set 4 | kondagaon
# Processing Record 33 of Set 4 | qandala
# Processing Record 34 of Set 4 | vao
# Processing Record 35 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 4 | ballina
# Processing Record 37 of Set 4 | dingle
# Processing Record 38 of Set 4 | thinadhoo
# Processing Record 39 of Set 4 | hilo
# Processing Record 40 of Set 4 | kimparana
# Processing Record 41 of Set 4 | terenga
# City not found. Skipping...
# Processing Record 42 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 4 | araouane
# Processing Record 44 of Set 4 | tres arroyos
# Processing Record 45 of Set 4 | bathsheba
# Processing Record 46 of Set 4 | arti
# Processing Record 47 of Set 4 | itarema
# Processing Record 48 of Set 4 | bethel
# Processing Record 49 of Set 4 | preobrazheniye
# Processing Record 50 of Set 4 | vestmannaeyjar
# Processing Record 1 of Set 5 | dunedin
# Processing Record 2 of Set 5 | swanton
# Processing Record 3 of Set 5 | new norfolk
# Processing Record 4 of Set 5 | la romana
# Processing Record 5 of Set 5 | scarborough
# Processing Record 6 of Set 5 | barra patuca
# Processing Record 7 of Set 5 | nikolskoye
# Processing Record 8 of Set 5 | coruripe
# Processing Record 9 of Set 5 | lethem
# Processing Record 10 of Set 5 | carutapera
# Processing Record 11 of Set 5 | tiznit
# Processing Record 12 of Set 5 | coihaique
# Processing Record 13 of Set 5 | bayana
# Processing Record 14 of Set 5 | poum
# Processing Record 15 of Set 5 | newport
# Processing Record 16 of Set 5 | road town
# Processing Record 17 of Set 5 | thessalon
# Processing Record 18 of Set 5 | manjacaze
# Processing Record 19 of Set 5 | eidfjord
# Processing Record 20 of Set 5 | charlestown
# Processing Record 21 of Set 5 | concepcion del uruguay
# Processing Record 22 of Set 5 | nhulunbuy
# Processing Record 23 of Set 5 | kieta
# Processing Record 24 of Set 5 | chicama
# Processing Record 25 of Set 5 | dudinka
# Processing Record 26 of Set 5 | westport
# Processing Record 27 of Set 5 | campbell river
# Processing Record 28 of Set 5 | freeport
# Processing Record 29 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 5 | amnat charoen
# Processing Record 32 of Set 5 | fresno
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | oil city
# Processing Record 35 of Set 5 | kota belud
# Processing Record 36 of Set 5 | victoria
# Processing Record 37 of Set 5 | boende
# Processing Record 38 of Set 5 | chumikan
# Processing Record 39 of Set 5 | ilhabela
# Processing Record 40 of Set 5 | constitucion
# Processing Record 41 of Set 5 | roald
# Processing Record 42 of Set 5 | balaipungut
# Processing Record 43 of Set 5 | narsaq
# Processing Record 44 of Set 5 | pisco
# Processing Record 45 of Set 5 | watsa
# Processing Record 46 of Set 5 | srednekolymsk
# Processing Record 47 of Set 5 | kahului
# Processing Record 48 of Set 5 | farafangana
# Processing Record 49 of Set 5 | laguna
# Processing Record 50 of Set 5 | inhambane
# Processing Record 1 of Set 6 | mayor pablo lagerenza
# Processing Record 2 of Set 6 | vostok
# Processing Record 3 of Set 6 | payakumbuh
# Processing Record 4 of Set 6 | picota
# Processing Record 5 of Set 6 | nassau
# Processing Record 6 of Set 6 | namatanai
# Processing Record 7 of Set 6 | uarini
# Processing Record 8 of Set 6 | erenhot
# Processing Record 9 of Set 6 | chokurdakh
# Processing Record 10 of Set 6 | palana
# Processing Record 11 of Set 6 | tiksi
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | vangaindrano
# Processing Record 14 of Set 6 | lac du bonnet
# Processing Record 15 of Set 6 | a
# City not found. Skipping...
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | westerland
# Processing Record 18 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 6 | kalakamati
# Processing Record 20 of Set 6 | sur
# Processing Record 21 of Set 6 | kargasok
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | vanderhoof
# Processing Record 24 of Set 6 | san cristobal
# Processing Record 25 of Set 6 | linjiang
# Processing Record 26 of Set 6 | muros
# Processing Record 27 of Set 6 | cidreira
# Processing Record 28 of Set 6 | saldanha
# Processing Record 29 of Set 6 | saint george
# Processing Record 30 of Set 6 | gayeri
# Processing Record 31 of Set 6 | luau
# Processing Record 32 of Set 6 | arraial do cabo
# Processing Record 33 of Set 6 | joshimath
# Processing Record 34 of Set 6 | boa vista
# Processing Record 35 of Set 6 | arlit
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | atbasar
# Processing Record 38 of Set 6 | kiunga
# Processing Record 39 of Set 6 | buraydah
# Processing Record 40 of Set 6 | ambagarh chauki
# Processing Record 41 of Set 6 | inzer
# Processing Record 42 of Set 6 | mount gambier
# Processing Record 43 of Set 6 | fare
# Processing Record 44 of Set 6 | san quintin
# Processing Record 45 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 6 | umarkot
# Processing Record 47 of Set 6 | kenai
# Processing Record 48 of Set 6 | banda aceh
# Processing Record 49 of Set 6 | huangchuan
# Processing Record 50 of Set 6 | henties bay
# Processing Record 1 of Set 7 | grand bank
# Processing Record 2 of Set 7 | marsabit
# Processing Record 3 of Set 7 | adrar
# Processing Record 4 of Set 7 | leon
# Processing Record 5 of Set 7 | bataipora
# Processing Record 6 of Set 7 | quixada
# Processing Record 7 of Set 7 | katobu
# Processing Record 8 of Set 7 | raudeberg
# Processing Record 9 of Set 7 | sao pedro do sul
# Processing Record 10 of Set 7 | broken hill
# Processing Record 11 of Set 7 | nishihara
# Processing Record 12 of Set 7 | bandarbeyla
# Processing Record 13 of Set 7 | verkhnevilyuysk
# Processing Record 14 of Set 7 | houlung
# City not found. Skipping...
# Processing Record 15 of Set 7 | byron bay
# Processing Record 16 of Set 7 | chaman
# Processing Record 17 of Set 7 | butaritari
# Processing Record 18 of Set 7 | nhamunda
# Processing Record 19 of Set 7 | olafsvik
# Processing Record 20 of Set 7 | makinsk
# Processing Record 21 of Set 7 | albertville
# Processing Record 22 of Set 7 | elizabethtown
# Processing Record 23 of Set 7 | lotofaga
# Processing Record 24 of Set 7 | zaragoza
# Processing Record 25 of Set 7 | shizunai
# Processing Record 26 of Set 7 | warrington
# Processing Record 27 of Set 7 | loyga
# Processing Record 28 of Set 7 | jalu
# Processing Record 29 of Set 7 | penzance
# Processing Record 30 of Set 7 | conde
# Processing Record 31 of Set 7 | nome
# Processing Record 32 of Set 7 | hirara
# Processing Record 33 of Set 7 | tacoronte
# Processing Record 34 of Set 7 | bandar-e lengeh
# Processing Record 35 of Set 7 | hamilton
# Processing Record 36 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 7 | tarko-sale
# Processing Record 38 of Set 7 | ewa beach
# Processing Record 39 of Set 7 | parkes
# Processing Record 40 of Set 7 | chalmette
# Processing Record 41 of Set 7 | port hardy
# Processing Record 42 of Set 7 | qaqortoq
# Processing Record 43 of Set 7 | suoyarvi
# Processing Record 44 of Set 7 | baruun-urt
# Processing Record 45 of Set 7 | sao joao da barra
# Processing Record 46 of Set 7 | hofn
# Processing Record 47 of Set 7 | tabuk
# Processing Record 48 of Set 7 | sungaipenuh
# Processing Record 49 of Set 7 | donetsk
# Processing Record 50 of Set 7 | longyearbyen
# Processing Record 1 of Set 8 | fethiye
# Processing Record 2 of Set 8 | shingu
# Processing Record 3 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 8 | ponnani
# Processing Record 5 of Set 8 | mount pleasant
# Processing Record 6 of Set 8 | villa carlos paz
# Processing Record 7 of Set 8 | college
# Processing Record 8 of Set 8 | kodinsk
# Processing Record 9 of Set 8 | port blair
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | eureka
# Processing Record 12 of Set 8 | yining
# Processing Record 13 of Set 8 | bereda
# Processing Record 14 of Set 8 | mabaruma
# Processing Record 15 of Set 8 | provideniya
# Processing Record 16 of Set 8 | lipari
# Processing Record 17 of Set 8 | nabire
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | shieli
# Processing Record 20 of Set 8 | oistins
# Processing Record 21 of Set 8 | progreso
# Processing Record 22 of Set 8 | camana
# Processing Record 23 of Set 8 | sao filipe
# Processing Record 24 of Set 8 | belaya gora
# Processing Record 25 of Set 8 | kavaratti
# Processing Record 26 of Set 8 | kardasova recice
# Processing Record 27 of Set 8 | fortuna
# Processing Record 28 of Set 8 | nouadhibou
# Processing Record 29 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 8 | taltal
# Processing Record 31 of Set 8 | telenesti
# Processing Record 32 of Set 8 | yuzhno-sukhokumsk
# Processing Record 33 of Set 8 | aswan
# Processing Record 34 of Set 8 | atyrau
# Processing Record 35 of Set 8 | teya
# Processing Record 36 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 8 | sobolevo
# Processing Record 38 of Set 8 | nyuksenitsa
# Processing Record 39 of Set 8 | kupang
# Processing Record 40 of Set 8 | panjab
# Processing Record 41 of Set 8 | la palma
# Processing Record 42 of Set 8 | havoysund
# Processing Record 43 of Set 8 | maniitsoq
# Processing Record 44 of Set 8 | cabo san lucas
# Processing Record 45 of Set 8 | ravar
# Processing Record 46 of Set 8 | manhumirim
# Processing Record 47 of Set 8 | mehamn
# Processing Record 48 of Set 8 | vila velha
# Processing Record 49 of Set 8 | klichka
# Processing Record 50 of Set 8 | marsaxlokk
# Processing Record 1 of Set 9 | berlevag
# Processing Record 2 of Set 9 | zhengjiatun
# Processing Record 3 of Set 9 | nizhnyaya poyma
# Processing Record 4 of Set 9 | keshan
# City not found. Skipping...
# Processing Record 5 of Set 9 | hami
# Processing Record 6 of Set 9 | andros town
# Processing Record 7 of Set 9 | lavrentiya
# Processing Record 8 of Set 9 | visakhapatnam
# Processing Record 9 of Set 9 | barahona
# Processing Record 10 of Set 9 | smirnykh
# Processing Record 11 of Set 9 | nalut
# Processing Record 12 of Set 9 | kota bahru
# Processing Record 13 of Set 9 | saqqez
# Processing Record 14 of Set 9 | ferme-neuve
# Processing Record 15 of Set 9 | marawi
# Processing Record 16 of Set 9 | wolmaranstad
# City not found. Skipping...
# Processing Record 17 of Set 9 | rawson
# Processing Record 18 of Set 9 | nemuro
# Processing Record 19 of Set 9 | tuatapere
# Processing Record 20 of Set 9 | sakaiminato
# Processing Record 21 of Set 9 | parrita
# Processing Record 22 of Set 9 | rurrenabaque
# Processing Record 23 of Set 9 | komsomolskiy
# Processing Record 24 of Set 9 | huarmey
# Processing Record 25 of Set 9 | oranjemund
# Processing Record 26 of Set 9 | shenjiamen
# Processing Record 27 of Set 9 | oktyabrskiy
# Processing Record 28 of Set 9 | acapulco
# Processing Record 29 of Set 9 | fairbanks
# Processing Record 30 of Set 9 | aklavik
# Processing Record 31 of Set 9 | okhotsk
# Processing Record 32 of Set 9 | padang
# Processing Record 33 of Set 9 | teguldet
# Processing Record 34 of Set 9 | borba
# Processing Record 35 of Set 9 | shkotovo-26
# City not found. Skipping...
# Processing Record 36 of Set 9 | ambon
# Processing Record 37 of Set 9 | paamiut
# Processing Record 38 of Set 9 | sturgis
# Processing Record 39 of Set 9 | beaumont
# Processing Record 40 of Set 9 | beloomut
# Processing Record 41 of Set 9 | maragogi
# Processing Record 42 of Set 9 | leningradskiy
# Processing Record 43 of Set 9 | agropoli
# Processing Record 44 of Set 9 | asau
# Processing Record 45 of Set 9 | aksu
# Processing Record 46 of Set 9 | nadvoitsy
# Processing Record 47 of Set 9 | suntar
# Processing Record 48 of Set 9 | santa maria
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | nantucket
# Processing Record 1 of Set 10 | bakchar
# Processing Record 2 of Set 10 | walvis bay
# Processing Record 3 of Set 10 | cayenne
# Processing Record 4 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 10 | kuusamo
# Processing Record 6 of Set 10 | revelstoke
# Processing Record 7 of Set 10 | meadow lake
# Processing Record 8 of Set 10 | airai
# Processing Record 9 of Set 10 | turukhansk
# Processing Record 10 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 10 | burica
# City not found. Skipping...
# Processing Record 12 of Set 10 | acarau
# Processing Record 13 of Set 10 | susehri
# Processing Record 14 of Set 10 | ambilobe
# Processing Record 15 of Set 10 | peterhead
# Processing Record 16 of Set 10 | ponta delgada
# Processing Record 17 of Set 10 | mamallapuram
# Processing Record 18 of Set 10 | qasigiannguit
# Processing Record 19 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 10 | shkotovo-22
# City not found. Skipping...
# Processing Record 21 of Set 10 | raahe
# Processing Record 22 of Set 10 | srikakulam
# Processing Record 23 of Set 10 | dakar
# Processing Record 24 of Set 10 | zaysan
# Processing Record 25 of Set 10 | bongandanga
# Processing Record 26 of Set 10 | rocha
# Processing Record 27 of Set 10 | yarmouth
# Processing Record 28 of Set 10 | dryden
# Processing Record 29 of Set 10 | guadalupe y calvo
# Processing Record 30 of Set 10 | lodja
# Processing Record 31 of Set 10 | vila
# Processing Record 32 of Set 10 | horta
# Processing Record 33 of Set 10 | neftcala
# Processing Record 34 of Set 10 | kamaishi
# Processing Record 35 of Set 10 | masyaf
# Processing Record 36 of Set 10 | gizo
# Processing Record 37 of Set 10 | beira
# Processing Record 38 of Set 10 | pyu
# Processing Record 39 of Set 10 | passo fundo
# Processing Record 40 of Set 10 | uitenhage
# Processing Record 41 of Set 10 | araguari
# Processing Record 42 of Set 10 | bauchi
# Processing Record 43 of Set 10 | antigonish
# Processing Record 44 of Set 10 | lazarev
# Processing Record 45 of Set 10 | valparaiso
# Processing Record 46 of Set 10 | dali
# Processing Record 47 of Set 10 | ostrovnoy
# Processing Record 48 of Set 10 | aba
# Processing Record 49 of Set 10 | buchanan
# Processing Record 50 of Set 10 | beringovskiy
# Processing Record 1 of Set 11 | vagay
# Processing Record 2 of Set 11 | harper
# Processing Record 3 of Set 11 | olmos
# Processing Record 4 of Set 11 | chingirlau
# Processing Record 5 of Set 11 | miyazu
# Processing Record 6 of Set 11 | havre-saint-pierre
# Processing Record 7 of Set 11 | angra
# City not found. Skipping...
# Processing Record 8 of Set 11 | dalbandin
# Processing Record 9 of Set 11 | sefton
# Processing Record 10 of Set 11 | mastic beach
# Processing Record 11 of Set 11 | el alto
# Processing Record 12 of Set 11 | vila franca do campo
# Processing Record 13 of Set 11 | caraquet
# Processing Record 14 of Set 11 | yerbogachen
# Processing Record 15 of Set 11 | amuntai
# Processing Record 16 of Set 11 | san joaquin
# Processing Record 17 of Set 11 | opuwo
# Processing Record 18 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 19 of Set 11 | tateyama
# Processing Record 20 of Set 11 | ascension
# Processing Record 21 of Set 11 | salalah
# Processing Record 22 of Set 11 | kasangulu
# Processing Record 23 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 11 | igunga
# Processing Record 25 of Set 11 | sao felix do xingu
# Processing Record 26 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 27 of Set 11 | sterling
# Processing Record 28 of Set 11 | kruisfontein
# Processing Record 29 of Set 11 | vanimo
# Processing Record 30 of Set 11 | abu samrah
# Processing Record 31 of Set 11 | solano
# Processing Record 32 of Set 11 | labuan
# Processing Record 33 of Set 11 | saint-denis
# Processing Record 34 of Set 11 | forestville
# Processing Record 35 of Set 11 | visnes
# Processing Record 36 of Set 11 | grand gaube
# Processing Record 37 of Set 11 | muli
# Processing Record 38 of Set 11 | muscat
# Processing Record 39 of Set 11 | pennsville
# Processing Record 40 of Set 11 | zhigansk
# Processing Record 41 of Set 11 | iquitos
# Processing Record 42 of Set 11 | elbrus
# Processing Record 43 of Set 11 | srivardhan
# Processing Record 44 of Set 11 | kununurra
# Processing Record 45 of Set 11 | san agustin
# Processing Record 46 of Set 11 | sarh
# Processing Record 47 of Set 11 | lefka
# Processing Record 48 of Set 11 | lockport
# Processing Record 49 of Set 11 | altay
# Processing Record 50 of Set 11 | lapua
# Processing Record 1 of Set 12 | los algarrobos
# Processing Record 2 of Set 12 | magdagachi
# Processing Record 3 of Set 12 | alofi
# Processing Record 4 of Set 12 | carsamba
# Processing Record 5 of Set 12 | anadyr
# Processing Record 6 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 12 | dwarka
# Processing Record 8 of Set 12 | juneau
# Processing Record 9 of Set 12 | waingapu
# Processing Record 10 of Set 12 | port-cartier
# Processing Record 11 of Set 12 | channel-port aux basques
# Processing Record 12 of Set 12 | taksimo
# Processing Record 13 of Set 12 | amga
# Processing Record 14 of Set 12 | cockburn town
# Processing Record 15 of Set 12 | odweyne
# Processing Record 16 of Set 12 | sri aman
# Processing Record 17 of Set 12 | leticia
# Processing Record 18 of Set 12 | chute-aux-outardes
# Processing Record 19 of Set 12 | neyshabur
# Processing Record 20 of Set 12 | carnarvon
# Processing Record 21 of Set 12 | alihe
# Processing Record 22 of Set 12 | omboue
# Processing Record 23 of Set 12 | pevek
# Processing Record 24 of Set 12 | callaway
# Processing Record 25 of Set 12 | comodoro rivadavia
# Processing Record 26 of Set 12 | whitehorse
# Processing Record 27 of Set 12 | ko samui
# Processing Record 28 of Set 12 | mahebourg
# Processing Record 29 of Set 12 | haverfordwest
# Processing Record 30 of Set 12 | mizan teferi
# Processing Record 31 of Set 12 | biloela
# Processing Record 32 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 12 | zaykovo
# Processing Record 34 of Set 12 | smithers
# Processing Record 35 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 12 | jumla
# Processing Record 37 of Set 12 | impfondo
# Processing Record 38 of Set 12 | tiarei
# Processing Record 39 of Set 12 | kilifi
# Processing Record 40 of Set 12 | tonantins
# Processing Record 41 of Set 12 | novyy urengoy
# Processing Record 42 of Set 12 | viareggio
# Processing Record 43 of Set 12 | male
# Processing Record 44 of Set 12 | karaman
# Processing Record 45 of Set 12 | linares
# Processing Record 46 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 48 of Set 12 | north bend
# Processing Record 49 of Set 12 | alta floresta
# Processing Record 50 of Set 12 | anloga
# Processing Record 1 of Set 13 | emirdag
# Processing Record 2 of Set 13 | poykovskiy
# Processing Record 3 of Set 13 | saint anthony
# Processing Record 4 of Set 13 | yuzhnyy
# Processing Record 5 of Set 13 | tsabong
# Processing Record 6 of Set 13 | blind river
# Processing Record 7 of Set 13 | cruzilia
# Processing Record 8 of Set 13 | rosarito
# Processing Record 9 of Set 13 | baoding
# Processing Record 10 of Set 13 | upata
# Processing Record 11 of Set 13 | katha
# City not found. Skipping...
# Processing Record 12 of Set 13 | kassala
# Processing Record 13 of Set 13 | kutum
# Processing Record 14 of Set 13 | prattville
# Processing Record 15 of Set 13 | empangeni
# Processing Record 16 of Set 13 | wiwili
# Processing Record 17 of Set 13 | melbourne
# Processing Record 18 of Set 13 | saquarema
# Processing Record 19 of Set 13 | mangrol
# Processing Record 20 of Set 13 | mayumba
# Processing Record 21 of Set 13 | boca do acre
# Processing Record 22 of Set 13 | labateca
# Processing Record 23 of Set 13 | sorland
# Processing Record 24 of Set 13 | marrakesh
# Processing Record 25 of Set 13 | kaeo
# Processing Record 26 of Set 13 | manavgat
# Processing Record 27 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 13 | zyryanka
# Processing Record 29 of Set 13 | mossendjo
# Processing Record 30 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 13 | coahuayana
# Processing Record 32 of Set 13 | colomi
# Processing Record 33 of Set 13 | san jeronimo
# Processing Record 34 of Set 13 | caravelas
# Processing Record 35 of Set 13 | doha
# Processing Record 36 of Set 13 | makubetsu
# Processing Record 37 of Set 13 | cowansville
# Processing Record 38 of Set 13 | itoman
# Processing Record 39 of Set 13 | port augusta
# Processing Record 40 of Set 13 | abha
# Processing Record 41 of Set 13 | fushun
# Processing Record 42 of Set 13 | tokur
# Processing Record 43 of Set 13 | sikasso
# Processing Record 44 of Set 13 | norrtalje
# Processing Record 45 of Set 13 | sinnamary
# Processing Record 46 of Set 13 | kalininsk
# Processing Record 47 of Set 13 | birao
# Processing Record 48 of Set 13 | ishigaki
# Processing Record 49 of Set 13 | pontianak
# Processing Record 50 of Set 13 | san antonio
# Processing Record 1 of Set 14 | kindu
# Processing Record 2 of Set 14 | les escoumins
# Processing Record 3 of Set 14 | hillsboro
# Processing Record 4 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 5 of Set 14 | aguimes
# Processing Record 6 of Set 14 | pozo colorado
# Processing Record 7 of Set 14 | skibotn
# Processing Record 8 of Set 14 | baykit
# Processing Record 9 of Set 14 | peace river
# Processing Record 10 of Set 14 | djougou
# Processing Record 11 of Set 14 | januaria
# Processing Record 12 of Set 14 | benghazi
# Processing Record 13 of Set 14 | dutse
# Processing Record 14 of Set 14 | novobureyskiy
# Processing Record 15 of Set 14 | zhuanghe
# Processing Record 16 of Set 14 | shimoda
# Processing Record 17 of Set 14 | ayutla
# Processing Record 18 of Set 14 | dumas
# Processing Record 19 of Set 14 | hachinohe
# Processing Record 20 of Set 14 | koulamoutou
# Processing Record 21 of Set 14 | waipawa
# Processing Record 22 of Set 14 | gannan
# Processing Record 23 of Set 14 | cascais
# Processing Record 24 of Set 14 | margate
# Processing Record 25 of Set 14 | esperance
# Processing Record 26 of Set 14 | pyaozerskiy
# Processing Record 27 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 14 | sicamous
# Processing Record 29 of Set 14 | bambous virieux
# Processing Record 30 of Set 14 | farah
# Processing Record 31 of Set 14 | egvekinot
# Processing Record 32 of Set 14 | steamboat springs
# Processing Record 33 of Set 14 | tocopilla
# Processing Record 34 of Set 14 | mantua
# Processing Record 35 of Set 14 | palaikastron
# Processing Record 36 of Set 14 | navahrudak
# Processing Record 37 of Set 14 | zonguldak
# Processing Record 38 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 39 of Set 14 | denpasar
# Processing Record 40 of Set 14 | ternate
# Processing Record 41 of Set 14 | kurilsk
# Processing Record 42 of Set 14 | teguise
# Processing Record 43 of Set 14 | saint paul
# Processing Record 44 of Set 14 | byumba
# Processing Record 45 of Set 14 | puerto maldonado
# Processing Record 46 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 14 | khovu-aksy
# Processing Record 48 of Set 14 | minas
# Processing Record 49 of Set 14 | almas
# Processing Record 50 of Set 14 | lasa
# Processing Record 1 of Set 15 | saint-augustin
# Processing Record 2 of Set 15 | karratha
# Processing Record 3 of Set 15 | sili
# Processing Record 4 of Set 15 | tahoua
# Processing Record 5 of Set 15 | nizhniy kuranakh
# Processing Record 6 of Set 15 | south lake tahoe
# Processing Record 7 of Set 15 | nobeoka
# Processing Record 8 of Set 15 | conway
# Processing Record 9 of Set 15 | hurricane
# Processing Record 10 of Set 15 | kropotkin
# Processing Record 11 of Set 15 | dongsheng
# Processing Record 12 of Set 15 | cadillac
# Processing Record 13 of Set 15 | bubaque
# Processing Record 14 of Set 15 | tottori
# Processing Record 15 of Set 15 | camacha
# Processing Record 16 of Set 15 | kloulklubed
# Processing Record 17 of Set 15 | puerto gaitan
# Processing Record 18 of Set 15 | korla
# Processing Record 19 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 15 | izumo
# Processing Record 21 of Set 15 | play cu
# City not found. Skipping...
# Processing Record 22 of Set 15 | santa fe
# Processing Record 23 of Set 15 | fandriana
# Processing Record 24 of Set 15 | ghanzi
# Processing Record 25 of Set 15 | clearwater
# Processing Record 26 of Set 15 | agirish
# Processing Record 27 of Set 15 | mawlamyine
# Processing Record 28 of Set 15 | port hawkesbury
# Processing Record 29 of Set 15 | kyshtovka
# Processing Record 30 of Set 15 | santiago
# Processing Record 31 of Set 15 | nagato
# Processing Record 32 of Set 15 | mandalgovi
# Processing Record 33 of Set 15 | vardo
# Processing Record 34 of Set 15 | umm kaddadah
# Processing Record 35 of Set 15 | wamba
# Processing Record 36 of Set 15 | ozernovskiy
# Processing Record 37 of Set 15 | aksehir
# Processing Record 38 of Set 15 | mnogovershinnyy
# Processing Record 39 of Set 15 | biltine
# Processing Record 40 of Set 15 | plattsburgh
# Processing Record 41 of Set 15 | balkanabat
# Processing Record 42 of Set 15 | dergachi
# Processing Record 43 of Set 15 | faya
# Processing Record 44 of Set 15 | hatillo
# Processing Record 45 of Set 15 | linxia
# Processing Record 46 of Set 15 | belyy yar
# Processing Record 47 of Set 15 | tawang
# Processing Record 48 of Set 15 | moree
# Processing Record 49 of Set 15 | daru
# Processing Record 50 of Set 15 | naryan-mar
# Processing Record 1 of Set 16 | san juan del sur
# Processing Record 2 of Set 16 | fairmont
# Processing Record 3 of Set 16 | san rafael
# Processing Record 4 of Set 16 | meulaboh
# Processing Record 5 of Set 16 | sola
# Processing Record 6 of Set 16 | puerto escondido
# Processing Record 7 of Set 16 | saint-pierre
# Processing Record 8 of Set 16 | capim grosso
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bluff -46.6000  168.3333     59.81        91         100        5.64
# 1        Chuy -33.6971  -53.4616     74.01        59          57        8.12
# 2     Qaanaaq  77.4840  -69.3632     -7.38        85         100        4.74
# 3   Saskylakh  71.9167  114.0833    -13.81       100         100        2.26
# 4   Ketchikan  55.3422 -131.6461     35.58        93         100        3.44
# 5     Mataura -46.1927  168.8643     59.49        96          95        2.30
# 6      Albany  42.6001  -73.9662      6.51        51          12       14.00
# 7       Tabou   4.4230   -7.3528     86.36        63          30        6.13
# 8  Quang Ngai  15.1167  108.8000     72.55        92          97        4.72
# 9    Khatanga  71.9667  102.5000    -17.54        93         100        7.74
#
#   Country                 Date Current Description
# 0      NZ  2022-01-30 12:12:49     overcast clouds
# 1      UY  2022-01-30 12:12:49       broken clouds
# 2      GL  2022-01-30 12:12:49     overcast clouds
# 3      RU  2022-01-30 12:12:50     overcast clouds
# 4      US  2022-01-30 12:09:45     overcast clouds
# 5      NZ  2022-01-30 12:12:50     overcast clouds
# 6      US  2022-01-30 12:12:51          few clouds
# 7      CI  2022-01-30 12:12:51    scattered clouds
# 8      VN  2022-01-30 12:12:51     overcast clouds
# 9      RU  2022-01-30 12:12:52     overcast clouds

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df =city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0      Bluff      NZ  2022-01-30 12:12:49 -46.6000  168.3333     59.81
# 1       Chuy      UY  2022-01-30 12:12:49 -33.6971  -53.4616     74.01
# 2    Qaanaaq      GL  2022-01-30 12:12:49  77.4840  -69.3632     -7.38
# 3  Saskylakh      RU  2022-01-30 12:12:50  71.9167  114.0833    -13.81
# 4  Ketchikan      US  2022-01-30 12:09:45  55.3422 -131.6461     35.58
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        91         100        5.64     overcast clouds
# 1        59          57        8.12       broken clouds
# 2        85         100        4.74     overcast clouds
# 3       100         100        2.26     overcast clouds
# 4        93         100        3.44     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.head(3)
# Out:
#       City Country                 Date      Lat       Lng  Max Temp  \
# 0    Bluff      NZ  2022-01-30 12:12:49 -46.6000  168.3333     59.81
# 1     Chuy      UY  2022-01-30 12:12:49 -33.6971  -53.4616     74.01
# 2  Qaanaaq      GL  2022-01-30 12:12:49  77.4840  -69.3632     -7.38
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        91         100        5.64     overcast clouds
# 1        59          57        8.12       broken clouds
# 2        85         100        4.74     overcast clouds
